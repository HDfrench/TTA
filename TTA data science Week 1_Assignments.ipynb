# %%
from random import randint

# This is the function for completing task 1def task_1():
    # pick a random number between 1 and 9    rndnb = randint(1,10)
    # ask the user to enter his/her name    # as the inpu is a string, no check were added, although this means that an empty string could still be accepted as name    username = input("What is your name? ")
    # This is a generic while loop that will be always True    # You have to be careful with this as if you omit to break it, you can end up with a perpetual loop    while True:
        #This line is asking the user to input a number between 1 and 10        guess = input("I am thinking of a number between 1 and 10.\nWhat number do you think it is? ")
        # We are now going to try to check if the input provided is really an integer        # if something goes wrong in the try section, the code jumps immediately to the except section        try:
            # we first try to convert the input into an integer            gnb = int(guess)
            # if the conversion is successful, we check the input is within the expect range            # if it is not in the expected range, the code in the if statement is not executed and we repeat the while loop            if gnb in range(1,11):
                # we can now check if the picked number (rndnb ==> short of random number) is equal to the user input                if rndnb == gnb:
                    # if that is the case, we execute the next print statement                    # we use a single string containing the variable username as an integer between curly brackets                    # using the .format() containing the variable used in the string in the order they appear in the string                    print("Awesome {0}! You guessed right".format(username))
                else:
                    # if the number guessed and the number picked do not match, we print the next statement                    # still using the same .format structure, but this time we also show the number picked                    print("Nice try {0}, but my number was {1}".format(username, rndnb))
                # as the user input was an integer within the desired range, the code executed, so we can now escape the loop using the break statement                break
        # this is the except section that will be executed if something is wrong with the user input        except:
            # we do nothing            # simply restarting the while loop            pass

def task_2():
    my_jokes = ["What’s the best thing about Switzerland?\n\tI don’t know, but the flag is a big plus.",
               "I invented a new word!\n\tPlagiarism!", "Did you hear about the mathematician who’s afraid of negative numbers?\n\tHe’ll stop at nothing to avoid them.",
               "Why do we tell actors to “break a leg?”\n\tBecause every play has a cast.",
               "Helvetica and Times New Roman walk into a bar.\n\t“Get out of here!” shouts the bartender. “We don’t serve your type.”",
               "Yesterday I saw a guy spill all his Scrabble letters on the road.\n\tI asked him, “What’s the word on the street?”",
               "Hear about the new restaurant called Karma?\n\tThere’s no menu: You get what you deserve.",
               "A woman in labor suddenly shouted, “Shouldn’t! Wouldn’t! Couldn’t! Didn’t! Can’t!”\n\t“Don’t worry,” said the doc. “Those are just contractions.”",
               "A bear walks into a bar and says, “Give me a whiskey and … cola.”\n\t“Why the big pause?” asks the bartender. The bear shrugged. “I’m not sure; I was born with them.”",
               "Did you hear about the actor who fell through the floorboards?\n\tHe was just going through a stage.",
               "Did you hear about the claustrophobic astronaut?\n\tHe just needed a little space.",
               "Why don’t scientists trust atoms?\n\tBecause they make up everything.",
               "Why did the chicken go to the séance?\n\tTo get to the other side.",
               "Where are average things manufactured?\n\tThe satisfactory.",
               "How do you drown a hipster?\n\tThrow him in the mainstream.",
               "What sits at the bottom of the sea and twitches?\n\tA nervous wreck.",
               "Why can’t you explain puns to kleptomaniacs?\n\tThey always take things literally.",
               "A man tells his doctor, “Doc, help me. I’m addicted to Twitter!”\n\tThe doctor replies, “Sorry, I don’t follow you …”"]
    while True:
        guess = input("Pick a number between 1 and 100 ")
        try:
            gnb = int(guess)
            if gnb in range(1, 101):
                told_joke = (gnb%len(my_jokes))-1
                print(my_jokes[told_joke])
                break
        except:
            pass

def task_3():
    my_question = "What is your favorite "
    my_courses = ["starter", "main course", "dessert", "drink"]
    your_meal = []
    for course in my_courses:
        ans = input(my_question + course + "? ")
        your_meal.append(ans)

    print("Your favorite meal is ", end=" ")
    for ind in range(len(your_meal)-1):
        print(your_meal[ind], end=", ")
    print("and a glass of", your_meal[-1])

def task_4():
    print("If a motorbike costs £2000.00 in 2021, its value will be:")
    price = 2000.0
    year = 2021
    while price > 1000:
        price *=.9
        year +=1
        print(f"{year}\t £ {price:.2f}")

def task_5():
    numbers = []
    tasks = {"+": ["+","sum", "plus"],
            "-": ["-", "substraction", "minus"],
            "*": ["*", "product", "times"],
            "/": ["/", "division", "by"],
            "^": ["^", "factorisation", "to the power of"]}
    while len(numbers)<2:
        if len(numbers) == 0:
            nb = input("Input the first number: ")
        else:
            nb = input("Input the second number: ")
        try:
            val = float(nb)
            numbers.append(val)
        except:
            pass
    stg ="""Select an operator:
    \t+ for addtion
    \t- for substraction
    \t* for multiplication
    \t/ for division
    \t^ for factorisation\n"""
    while True:
        oper = input(stg)
        if oper in tasks.keys():
            break

    mycalculation = tasks[oper]
    if mycalculation[0] == "+":
        result = numbers[0] + numbers[1]
    elif mycalculation[0] == "-":
        result = numbers[0] - numbers[1]
    elif mycalculation[0] == "*":
        result = numbers[0] * numbers[1]
    elif mycalculation[0] == "/":
        if numbers[1] != 0:
            result = numbers[0] / numbers[1]
        else:
            result = None
            print("Division by 0!\nImpossible!!")
    else:
        result = numbers[0]**numbers[1]

    if result !=None:
        print("The {0} of {1} {2} {3} is {4}".format(mycalculation[1], numbers[0], mycalculation[2], numbers[1], result))



while True:
    user_choice = """What game would you like to play?
    \t1 - The guessing number game
    \t2 - The joke of the day
    \t3 - Your favorite meal
    \t4 - Motorbike depreciation
    \t5 - Two number calculator\n"""
    selec = input(user_choice)
    try:
        not_right = False
        jeu = int(selec)
        if jeu == 1:
            task_1()
        elif jeu == 2:
            task_2()
        elif jeu == 3:
            task_3()
        elif jeu == 4:
            task_4()
        elif jeu == 5:
            task_5()
        else:
            not_right = True

        if not_right == False:
            play_again = input("Do you want to play another game? ")
            if play_again.lower() != "y":
                break
    except:
        pass
# Out:
# What game would you like to play?
#     	1 - The guessing number game
#     	2 - The joke of the day
#     	3 - Your favorite meal
#     	4 - Motorbike depreciation
#     	5 - Two number calculator
# 2
# Pick a number between 1 and 100 74
# I invented a new word!
# 	Plagiarism!
# Do you want to play another game? y
# What game would you like to play?
#     	1 - The guessing number game
#     	2 - The joke of the day
#     	3 - Your favorite meal
#     	4 - Motorbike depreciation
#     	5 - Two number calculator
# 3
# What is your favorite starter? cucumber salad
# What is your favorite main course? lamb in mint sauce
# What is your favorite dessert? chocolate mousse
# What is your favorite drink? Saint Estephe
# Your favorite meal is  cucumber salad, lamb in mint sauce, chocolate mousse, and a glass of Saint Estephe
# Do you want to play another game? y
# What game would you like to play?
#     	1 - The guessing number game
#     	2 - The joke of the day
# ...
